# %%
import twitter
import pandas as pd

# %%
consumer_key = '3hadC5cGfmdfYqVQ3EClF0VZd'
secret_key ='kjIfrQrSokxLirRZ21HstrJOJQZvuM9FmUDkNpRYrYjmhLtyWK'

access_token = '374743137-e4C4fLpqDqfjv7dVpe5S9SFQbWKZ9Ii8ci3dFa53'
secret_token = 'tGsYrurk2euQwZwaf2vZeuJCBQNTTYl7tiPmF7Qqffq2S'

# %%
from twitter import *
t = twitter.api.Twitter(auth=OAuth(access_token , secret_token, consumer_key, secret_key))
t.statuses.home_timeline()
# Out:
# [{'created_at': 'Sat Apr 04 15:24:38 +0000 2020',
#   'id': 1246458663654559744,
#   'id_str': '1246458663654559744',
#   'text': 'You gotta respect concision. https://t.co/I1onV69Kv5',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/I1onV69Kv5',
#      'expanded_url': 'https://twitter.com/sidleykate/status/1246433310638772225',
#      'display_url': 'twitter.com/sidleykate/sta…',
#      'indices': [29, 52]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16303106,
#    'id_str': '16303106',
#    'name': 'Stephen Colbert',
#    'screen_name': 'StephenAtHome',
#    'location': '',
#    'description': 'the guy on CBS',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 18794957,
#    'friends_count': 47,
#    'listed_count': 68350,
#    'created_at': 'Mon Sep 15 22:31:44 +0000 2008',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 6393,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/627669832549441536/hv1AMpO0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/627669832549441536/hv1AMpO0_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16303106/1440595314',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1246433310638772225,
#   'quoted_status_id_str': '1246433310638772225',
#   'quoted_status': {'created_at': 'Sat Apr 04 13:43:53 +0000 2020',
#    'id': 1246433310638772225,
#    'id_str': '1246433310638772225',
#    'text': 'I miss Cleveland so much. https://t.co/3UY5XrJ3Vb',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/3UY5XrJ3Vb',
#       'expanded_url': 'https://twitter.com/abbyhoward26/status/1245510918299103232',
#       'display_url': 'twitter.com/abbyhoward26/s…',
#       'indices': [26, 49]}]},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 328806986,
#     'id_str': '328806986',
#     'name': 'Kate Sidley',
#     'screen_name': 'sidleykate',
#     'location': 'New York, NY',
#     'description': 'Writer at @colbertlateshow | co-founder @SeaTeaImprov | professional joke maker | child of Cleveland',
#     'url': 'https://t.co/wpGx5msaTt',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/wpGx5msaTt',
#         'expanded_url': 'http://katesidley.com',
#         'display_url': 'katesidley.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5276,
#     'friends_count': 1435,
#     'listed_count': 90,
#     'created_at': 'Mon Jul 04 02:12:23 +0000 2011',
#     'favourites_count': 19639,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 3879,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '709397',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/871464625480638469/2pVK5AJj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/871464625480638469/2pVK5AJj_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/328806986/1431362787',
#     'profile_link_color': 'FF3300',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFF7CC',
#     'profile_text_color': '0C3E53',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1245510918299103232,
#    'quoted_status_id_str': '1245510918299103232',
#    'retweet_count': 38,
#    'favorite_count': 215,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'retweet_count': 42,
#   'favorite_count': 596,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Apr 04 00:57:57 +0000 2020',
#   'id': 1246240556726059008,
#   'id_str': '1246240556726059008',
#   'text': 'The last two weeks have been a strange ten years.',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16303106,
#    'id_str': '16303106',
#    'name': 'Stephen Colbert',
#    'screen_name': 'StephenAtHome',
#    'location': '',
#    'description': 'the guy on CBS',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 18794957,
#    'friends_count': 47,
#    'listed_count': 68350,
#    'created_at': 'Mon Sep 15 22:31:44 +0000 2008',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 6393,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/627669832549441536/hv1AMpO0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/627669832549441536/hv1AMpO0_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16303106/1440595314',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 35946,
#   'favorite_count': 226575,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Apr 03 23:00:51 +0000 2020',
#   'id': 1246211088926027777,
#   'id_str': '1246211088926027777',
#   'text': 'RT @ChelseyMooner: Indig pow wow baddies want in on this #PasstheBrushChallenge !!! https://t.co/GA763stfiA',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'PasstheBrushChallenge',
#      'indices': [57, 79]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ChelseyMooner',
#      'name': 'niigaanaasnok',
#      'id': 935617448409206785,
#      'id_str': '935617448409206785',
#      'indices': [3, 17]}],
#    'urls': [],
#    'media': [{'id': 1245800293482270721,
#      'id_str': '1245800293482270721',
#      'indices': [84, 107],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245800293482270721/pu/img/kUCX_Heeb2YriGfO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245800293482270721/pu/img/kUCX_Heeb2YriGfO.jpg',
#      'url': 'https://t.co/GA763stfiA',
#      'display_url': 'pic.twitter.com/GA763stfiA',
#      'expanded_url': 'https://twitter.com/ChelseyMooner/status/1245800510948552706/video/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 720, 'h': 900, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 720, 'h': 900, 'resize': 'fit'}},
#      'source_status_id': 1245800510948552706,
#      'source_status_id_str': '1245800510948552706',
#      'source_user_id': 935617448409206785,
#      'source_user_id_str': '935617448409206785'}]},
#   'extended_entities': {'media': [{'id': 1245800293482270721,
#      'id_str': '1245800293482270721',
#      'indices': [84, 107],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245800293482270721/pu/img/kUCX_Heeb2YriGfO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245800293482270721/pu/img/kUCX_Heeb2YriGfO.jpg',
#      'url': 'https://t.co/GA763stfiA',
#      'display_url': 'pic.twitter.com/GA763stfiA',
#      'expanded_url': 'https://twitter.com/ChelseyMooner/status/1245800510948552706/video/1',
#      'type': 'video',
#      'sizes': {'large': {'w': 720, 'h': 900, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 720, 'h': 900, 'resize': 'fit'}},
#      'source_status_id': 1245800510948552706,
#      'source_status_id_str': '1245800510948552706',
#      'source_user_id': 935617448409206785,
#      'source_user_id_str': '935617448409206785',
#      'video_info': {'aspect_ratio': [4, 5],
#       'duration_millis': 75700,
#       'variants': [{'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1245800293482270721/pu/vid/360x450/yxOox9Y0xgkV-vaZ.mp4?tag=10'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1245800293482270721/pu/pl/SH4tj3pXRKGW5ueu.m3u8?tag=10'},
#        {'bitrate': 632000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1245800293482270721/pu/vid/320x400/W2-PnD4MQ_opQTNe.mp4?tag=10'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1245800293482270721/pu/vid/720x900/3cJg_u6L0z_DZNx3.mp4?tag=10'}]},
#      'additional_media_info': {'monetizable': False,
#       'source_user': {'id': 935617448409206785,
#        'id_str': '935617448409206785',
#        'name': 'niigaanaasnok',
#        'screen_name': 'ChelseyMooner',
#        'location': 'Bahweting, MI',
#        'description': 'Ojibwe. 🐺 Androgynous. She/Her. YouTuber. 🤟🏻',
#        'url': 'https://t.co/FsaY8bUPoB',
#        'entities': {'url': {'urls': [{'url': 'https://t.co/FsaY8bUPoB',
#            'expanded_url': 'https://www.youtube.com/c/ChelseyMoon',
#            'display_url': 'youtube.com/c/ChelseyMoon',
#            'indices': [0, 23]}]},
#         'description': {'urls': []}},
#        'protected': False,
#        'followers_count': 6051,
#        'friends_count': 2381,
#        'listed_count': 14,
#        'created_at': 'Tue Nov 28 21:12:37 +0000 2017',
#        'favourites_count': 71500,
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': True,
#        'verified': False,
#        'statuses_count': 15938,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'is_translation_enabled': False,
#        'profile_background_color': 'F5F8FA',
#        'profile_background_image_url': None,
#        'profile_background_image_url_https': None,
#        'profile_background_tile': False,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/1211058073298722825/hI6EJMkW_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211058073298722825/hI6EJMkW_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/935617448409206785/1532873720',
#        'profile_link_color': '1DA1F2',
#        'profile_sidebar_border_color': 'C0DEED',
#        'profile_sidebar_fill_color': 'DDEEF6',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'has_extended_profile': True,
#        'default_profile': True,
#        'default_profile_image': False,
#        'following': False,
#        'follow_request_sent': False,
#        'notifications': False,
#        'translator_type': 'none'}}}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25940364,
#    'id_str': '25940364',
#    'name': 'Grace Bonney',
#    'screen_name': 'designsponge',
#    'location': 'Ulster County, New York',
#    'description': 'Writer + Founder: Design*Sponge 🖥 Good Company Magazine 📕 In the Company of Women 📚 Proud 🌈',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 537358,
#    'friends_count': 4948,
#    'listed_count': 8528,
#    'created_at': 'Mon Mar 23 02:59:40 +0000 2009',
#    'favourites_count': 26564,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 65874,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F2F2F2',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1220522709312049152/w6q2dAh3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220522709312049152/w6q2dAh3_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25940364/1566319992',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'FCF8F7',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Apr 02 19:49:22 +0000 2020',
#    'id': 1245800510948552706,
#    'id_str': '1245800510948552706',
#    'text': 'Indig pow wow baddies want in on this #PasstheBrushChallenge !!! https://t.co/GA763stfiA',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'PasstheBrushChallenge',
#       'indices': [38, 60]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1245800293482270721,
#       'id_str': '1245800293482270721',
#       'indices': [65, 88],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245800293482270721/pu/img/kUCX_Heeb2YriGfO.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245800293482270721/pu/img/kUCX_Heeb2YriGfO.jpg',
#       'url': 'https://t.co/GA763stfiA',
#       'display_url': 'pic.twitter.com/GA763stfiA',
#       'expanded_url': 'https://twitter.com/ChelseyMooner/status/1245800510948552706/video/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 720, 'h': 900, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 720, 'h': 900, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1245800293482270721,
#       'id_str': '1245800293482270721',
#       'indices': [65, 88],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245800293482270721/pu/img/kUCX_Heeb2YriGfO.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245800293482270721/pu/img/kUCX_Heeb2YriGfO.jpg',
#       'url': 'https://t.co/GA763stfiA',
#       'display_url': 'pic.twitter.com/GA763stfiA',
#       'expanded_url': 'https://twitter.com/ChelseyMooner/status/1245800510948552706/video/1',
#       'type': 'video',
#       'sizes': {'large': {'w': 720, 'h': 900, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 720, 'h': 900, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [4, 5],
#        'duration_millis': 75700,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1245800293482270721/pu/vid/360x450/yxOox9Y0xgkV-vaZ.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1245800293482270721/pu/pl/SH4tj3pXRKGW5ueu.m3u8?tag=10'},
#         {'bitrate': 632000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1245800293482270721/pu/vid/320x400/W2-PnD4MQ_opQTNe.mp4?tag=10'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1245800293482270721/pu/vid/720x900/3cJg_u6L0z_DZNx3.mp4?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 935617448409206785,
#     'id_str': '935617448409206785',
#     'name': 'niigaanaasnok',
#     'screen_name': 'ChelseyMooner',
#     'location': 'Bahweting, MI',
#     'description': 'Ojibwe. 🐺 Androgynous. She/Her. YouTuber. 🤟🏻',
#     'url': 'https://t.co/FsaY8bUPoB',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/FsaY8bUPoB',
#         'expanded_url': 'https://www.youtube.com/c/ChelseyMoon',
#         'display_url': 'youtube.com/c/ChelseyMoon',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6051,
#     'friends_count': 2381,
#     'listed_count': 14,
#     'created_at': 'Tue Nov 28 21:12:37 +0000 2017',
#     'favourites_count': 71500,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 15938,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1211058073298722825/hI6EJMkW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211058073298722825/hI6EJMkW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/935617448409206785/1532873720',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2349,
#    'favorite_count': 8778,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2349,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Apr 03 22:10:33 +0000 2020',
#   'id': 1246198430600499200,
#   'id_str': '1246198430600499200',
#   'text': 'We’re all staying in these days, so it’s only fitting our guests this week are the hosts of the new podcast “Stayin… https://t.co/UAk6KKtKT9',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/UAk6KKtKT9',
#      'expanded_url': 'https://twitter.com/i/web/status/1246198430600499200',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 13784322,
#    'id_str': '13784322',
#    'name': 'waitwait',
#    'screen_name': 'waitwait',
#    'location': 'Chicago, USA',
#    'description': 'The oddly informative news quiz from NPR',
#    'url': 'http://t.co/rAlUqTdOgD',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/rAlUqTdOgD',
#        'expanded_url': 'http://waitwait.npr.org',
#        'display_url': 'waitwait.npr.org',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 190309,
#    'friends_count': 222,
#    'listed_count': 4567,
#    'created_at': 'Thu Feb 21 19:29:43 +0000 2008',
#    'favourites_count': 1571,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 7455,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1179055744076976128/pj3hu6NS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1179055744076976128/pj3hu6NS_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/13784322/1533135725',
#    'profile_link_color': '089FD6',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'D8E6ED',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 26,
#   'favorite_count': 505,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Apr 03 21:43:32 +0000 2020',
#   'id': 1246191630169899014,
#   'id_str': '1246191630169899014',
#   'text': '#RealLifeAtHome https://t.co/ilvDma4PIV',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'RealLifeAtHome', 'indices': [0, 15]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1246191323406835714,
#      'id_str': '1246191323406835714',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1246191323406835714/img/1Owpjn6bjFyEJxSL.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1246191323406835714/img/1Owpjn6bjFyEJxSL.jpg',
#      'url': 'https://t.co/ilvDma4PIV',
#      'display_url': 'pic.twitter.com/ilvDma4PIV',
#      'expanded_url': 'https://twitter.com/TheEllenShow/status/1246191630169899014/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 720, 'h': 1280, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1246191323406835714,
#      'id_str': '1246191323406835714',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1246191323406835714/img/1Owpjn6bjFyEJxSL.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1246191323406835714/img/1Owpjn6bjFyEJxSL.jpg',
#      'url': 'https://t.co/ilvDma4PIV',
#      'display_url': 'pic.twitter.com/ilvDma4PIV',
#      'expanded_url': 'https://twitter.com/TheEllenShow/status/1246191630169899014/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 720, 'h': 1280, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [9, 16],
#       'duration_millis': 20600,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1246191323406835714/pl/WluSj7qALjrrtAE4.m3u8?tag=13'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1246191323406835714/vid/720x1280/LZ-OzUpqFZBCosS4.mp4?tag=13'},
#        {'bitrate': 632000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1246191323406835714/vid/320x568/4_0Uc7x61zIxILWK.mp4?tag=13'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1246191323406835714/vid/360x640/NLg4D2xC6G7tlMSn.mp4?tag=13'}]},
#      'additional_media_info': {'title': '',
#       'description': '',
#       'embeddable': True,
#       'monetizable': True}}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15846407,
#    'id_str': '15846407',
#    'name': 'Ellen DeGeneres',
#    'screen_name': 'TheEllenShow',
#    'location': 'California',
#    'description': 'Comedian, talk show host and ice road trucker. My tweets are real, and they’re spectacular. @ellentube @theellenfund',
#    'url': 'https://t.co/Z6A8XcDD9J',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Z6A8XcDD9J',
#        'expanded_url': 'https://www.ellentube.com/',
#        'display_url': 'ellentube.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 80001377,
#    'friends_count': 27590,
#    'listed_count': 107075,
#    'created_at': 'Thu Aug 14 03:50:42 +0000 2008',
#    'favourites_count': 2137,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 21597,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '3ABEE3',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15846407/1578444252',
#    'profile_link_color': '3ABEE3',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C4C6CC',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 311,
#   'favorite_count': 6917,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'und'},
#  {'created_at': 'Fri Apr 03 19:31:46 +0000 2020',
#   'id': 1246158469520130049,
#   'id_str': '1246158469520130049',
#   'text': 'Happy birthday, @AlecBaldwin, Eddie Murphy and Jane Goodall... otherwise known as my first dinner party guests after quarantine!',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AlecBaldwin',
#      'name': 'AlecBaldwin',
#      'id': 703808448,
#      'id_str': '703808448',
#      'indices': [16, 28]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15846407,
#    'id_str': '15846407',
#    'name': 'Ellen DeGeneres',
#    'screen_name': 'TheEllenShow',
#    'location': 'California',
#    'description': 'Comedian, talk show host and ice road trucker. My tweets are real, and they’re spectacular. @ellentube @theellenfund',
#    'url': 'https://t.co/Z6A8XcDD9J',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Z6A8XcDD9J',
#        'expanded_url': 'https://www.ellentube.com/',
#        'display_url': 'ellentube.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 80001377,
#    'friends_count': 27590,
#    'listed_count': 107075,
#    'created_at': 'Thu Aug 14 03:50:42 +0000 2008',
#    'favourites_count': 2137,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 21597,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '3ABEE3',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15846407/1578444252',
#    'profile_link_color': '3ABEE3',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C4C6CC',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 149,
#   'favorite_count': 3859,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Apr 03 18:58:30 +0000 2020',
#   'id': 1246150099446706176,
#   'id_str': '1246150099446706176',
#   'text': 'In time for a weekend nesting indoors: What We Loved This Week, including virtual global tours, 89 easy recipes fro… https://t.co/wQe37y6cPL',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/wQe37y6cPL',
#      'expanded_url': 'https://twitter.com/i/web/status/1246150099446706176',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 19789726,
#    'id_str': '19789726',
#    'name': 'One Kings Lane',
#    'screen_name': 'onekingslane',
#    'location': '',
#    'description': 'Insider access to all things One Kings Lane!',
#    'url': 'http://t.co/v6Ejes2faT',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/v6Ejes2faT',
#        'expanded_url': 'http://www.OneKingsLane.com',
#        'display_url': 'OneKingsLane.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 49149,
#    'friends_count': 1056,
#    'listed_count': 868,
#    'created_at': 'Fri Jan 30 21:28:00 +0000 2009',
#    'favourites_count': 2828,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 18671,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'CCCCCC',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1047117521814544385/N0YtJ_6n_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1047117521814544385/N0YtJ_6n_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19789726/1491341027',
#    'profile_link_color': '436B34',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F2F2F2',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Apr 03 18:34:01 +0000 2020',
#   'id': 1246143937615671296,
#   'id_str': '1246143937615671296',
#   'text': 'Who wore it better? https://t.co/bddNgeKy7I',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1246143887686733824,
#      'id_str': '1246143887686733824',
#      'indices': [20, 43],
#      'media_url': 'http://pbs.twimg.com/media/EUsxQ3SXkAAKb22.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EUsxQ3SXkAAKb22.jpg',
#      'url': 'https://t.co/bddNgeKy7I',
#      'display_url': 'pic.twitter.com/bddNgeKy7I',
#      'expanded_url': 'https://twitter.com/TheEllenShow/status/1246143937615671296/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 498, 'resize': 'fit'},
#       'large': {'w': 2048, 'h': 1501, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 879, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1246143887686733824,
#      'id_str': '1246143887686733824',
#      'indices': [20, 43],
#      'media_url': 'http://pbs.twimg.com/media/EUsxQ3SXkAAKb22.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EUsxQ3SXkAAKb22.jpg',
#      'url': 'https://t.co/bddNgeKy7I',
#      'display_url': 'pic.twitter.com/bddNgeKy7I',
#      'expanded_url': 'https://twitter.com/TheEllenShow/status/1246143937615671296/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 498, 'resize': 'fit'},
#       'large': {'w': 2048, 'h': 1501, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 879, 'resize': 'fit'}}}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15846407,
#    'id_str': '15846407',
#    'name': 'Ellen DeGeneres',
#    'screen_name': 'TheEllenShow',
#    'location': 'California',
#    'description': 'Comedian, talk show host and ice road trucker. My tweets are real, and they’re spectacular. @ellentube @theellenfund',
#    'url': 'https://t.co/Z6A8XcDD9J',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Z6A8XcDD9J',
#        'expanded_url': 'https://www.ellentube.com/',
#        'display_url': 'ellentube.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 80001377,
#    'friends_count': 27590,
#    'listed_count': 107075,
#    'created_at': 'Thu Aug 14 03:50:42 +0000 2008',
#    'favourites_count': 2137,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 21597,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '3ABEE3',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15846407/1578444252',
#    'profile_link_color': '3ABEE3',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C4C6CC',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2765,
#   'favorite_count': 60566,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Apr 03 16:32:56 +0000 2020',
#   'id': 1246113464185229315,
#   'id_str': '1246113464185229315',
#   'text': "I'm back. Monday. @official_tWitch @chrissyteigen @johnlegend https://t.co/OvndUMSQdE",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'official_tWitch',
#      'name': 'Stephen tWitch Boss',
#      'id': 49381709,
#      'id_str': '49381709',
#      'indices': [18, 34]},
#     {'screen_name': 'chrissyteigen',
#      'name': 'chrissy teigen',
#      'id': 39364684,
#      'id_str': '39364684',
#      'indices': [35, 49]},
#     {'screen_name': 'johnlegend',
#      'name': 'John Legend',
#      'id': 18228898,
#      'id_str': '18228898',
#      'indices': [50, 61]}],
#    'urls': [],
#    'media': [{'id': 1246113399722913798,
#      'id_str': '1246113399722913798',
#      'indices': [62, 85],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1246113399722913798/pu/img/vvMpG4xaEoXcty6t.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1246113399722913798/pu/img/vvMpG4xaEoXcty6t.jpg',
#      'url': 'https://t.co/OvndUMSQdE',
#      'display_url': 'pic.twitter.com/OvndUMSQdE',
#      'expanded_url': 'https://twitter.com/TheEllenShow/status/1246113464185229315/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 720, 'h': 1280, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1246113399722913798,
#      'id_str': '1246113399722913798',
#      'indices': [62, 85],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1246113399722913798/pu/img/vvMpG4xaEoXcty6t.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1246113399722913798/pu/img/vvMpG4xaEoXcty6t.jpg',
#      'url': 'https://t.co/OvndUMSQdE',
#      'display_url': 'pic.twitter.com/OvndUMSQdE',
#      'expanded_url': 'https://twitter.com/TheEllenShow/status/1246113464185229315/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 720, 'h': 1280, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [9, 16],
#       'duration_millis': 32202,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1246113399722913798/pu/pl/mVSt4qrzA-kT5A27.m3u8?tag=10'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1246113399722913798/pu/vid/360x640/OOy1MGLlWmeQCDTU.mp4?tag=10'},
#        {'bitrate': 632000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1246113399722913798/pu/vid/320x568/Cdknn7KJ8PJQnT85.mp4?tag=10'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1246113399722913798/pu/vid/720x1280/qBawh73jeBCFrPzA.mp4?tag=10'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15846407,
#    'id_str': '15846407',
#    'name': 'Ellen DeGeneres',
#    'screen_name': 'TheEllenShow',
#    'location': 'California',
#    'description': 'Comedian, talk show host and ice road trucker. My tweets are real, and they’re spectacular. @ellentube @theellenfund',
#    'url': 'https://t.co/Z6A8XcDD9J',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Z6A8XcDD9J',
#        'expanded_url': 'https://www.ellentube.com/',
#        'display_url': 'ellentube.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 80001377,
#    'friends_count': 27590,
#    'listed_count': 107075,
#    'created_at': 'Thu Aug 14 03:50:42 +0000 2008',
#    'favourites_count': 2137,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 21597,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '3ABEE3',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15846407/1578444252',
#    'profile_link_color': '3ABEE3',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C4C6CC',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1010,
#   'favorite_count': 19065,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Apr 03 16:31:19 +0000 2020',
#   'id': 1246113058856017928,
#   'id_str': '1246113058856017928',
#   'text': 'It was an honor to meet Mr. Withers. Yessir, many thanks for all you said through your songs. #LeanOnMe https://t.co/w1edJLsxs2',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'LeanOnMe', 'indices': [94, 103]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/w1edJLsxs2',
#      'expanded_url': 'https://twitter.com/jonbatiste/status/1246108617612369922',
#      'display_url': 'twitter.com/jonbatiste/sta…',
#      'indices': [104, 127]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16303106,
#    'id_str': '16303106',
#    'name': 'Stephen Colbert',
#    'screen_name': 'StephenAtHome',
#    'location': '',
#    'description': 'the guy on CBS',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 18794957,
#    'friends_count': 47,
#    'listed_count': 68350,
#    'created_at': 'Mon Sep 15 22:31:44 +0000 2008',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 6393,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/627669832549441536/hv1AMpO0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/627669832549441536/hv1AMpO0_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16303106/1440595314',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1246108617612369922,
#   'quoted_status_id_str': '1246108617612369922',
#   'quoted_status': {'created_at': 'Fri Apr 03 16:13:40 +0000 2020',
#    'id': 1246108617612369922,
#    'id_str': '1246108617612369922',
#    'text': 'Thank you Mr. Withers https://t.co/vrzbkOg5HB',
#    'truncated': False,
# ...
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 185519,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1245788681262305281/pl/2Jrqh0gBfffD8mxh.m3u8?tag=13'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1245788681262305281/vid/640x360/YNNDZUFD6a32p_1l.mp4?tag=13'},
#        {'bitrate': 288000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1245788681262305281/vid/480x270/9J1SiUsYhxN92A4W.mp4?tag=13'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1245788681262305281/vid/1280x720/7rAaAmUeeLCi9b-o.mp4?tag=13'}]},
#      'additional_media_info': {'title': '',
#       'description': '',
#       'embeddable': True,
#       'monetizable': True}}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15846407,
#    'id_str': '15846407',
#    'name': 'Ellen DeGeneres',
#    'screen_name': 'TheEllenShow',
#    'location': 'California',
#    'description': 'Comedian, talk show host and ice road trucker. My tweets are real, and they’re spectacular. @ellentube @theellenfund',
#    'url': 'https://t.co/Z6A8XcDD9J',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Z6A8XcDD9J',
#        'expanded_url': 'https://www.ellentube.com/',
#        'display_url': 'ellentube.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 80001377,
#    'friends_count': 27590,
#    'listed_count': 107075,
#    'created_at': 'Thu Aug 14 03:50:42 +0000 2008',
#    'favourites_count': 2137,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 21597,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '3ABEE3',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15846407/1578444252',
#    'profile_link_color': '3ABEE3',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C4C6CC',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 135,
#   'favorite_count': 1451,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 02 20:33:08 +0000 2020',
#   'id': 1245811527724253184,
#   'id_str': '1245811527724253184',
#   'text': 'This is the first place I’m visiting after this. https://t.co/u7iVulXw63',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/u7iVulXw63',
#      'expanded_url': 'https://twitter.com/ITVWales/status/1244947256937271297',
#      'display_url': 'twitter.com/ITVWales/statu…',
#      'indices': [49, 72]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15846407,
#    'id_str': '15846407',
#    'name': 'Ellen DeGeneres',
#    'screen_name': 'TheEllenShow',
#    'location': 'California',
#    'description': 'Comedian, talk show host and ice road trucker. My tweets are real, and they’re spectacular. @ellentube @theellenfund',
#    'url': 'https://t.co/Z6A8XcDD9J',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Z6A8XcDD9J',
#        'expanded_url': 'https://www.ellentube.com/',
#        'display_url': 'ellentube.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 80001377,
#    'friends_count': 27590,
#    'listed_count': 107075,
#    'created_at': 'Thu Aug 14 03:50:42 +0000 2008',
#    'favourites_count': 2137,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 21597,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '3ABEE3',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15846407/1578444252',
#    'profile_link_color': '3ABEE3',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C4C6CC',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1244947256937271297,
#   'quoted_status_id_str': '1244947256937271297',
#   'quoted_status': {'created_at': 'Tue Mar 31 11:18:50 +0000 2020',
#    'id': 1244947256937271297,
#    'id_str': '1244947256937271297',
#    'text': "Llandudno has had some unusual visitors! Mountain goats have been making the most of the town's quiet streets. 🐐… https://t.co/rcxeDGusrN",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/rcxeDGusrN',
#       'expanded_url': 'https://twitter.com/i/web/status/1244947256937271297',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 166942410,
#     'id_str': '166942410',
#     'name': 'ITV Wales News',
#     'screen_name': 'ITVWales',
#     'location': 'Wales',
#     'description': 'The latest news, sport & entertainment for Wales. Contact us: wales@itv.com - https://t.co/p0kGsvP13M - https://t.co/nDcD2LUq2d',
#     'url': 'http://t.co/CkDL0Cne9s',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/CkDL0Cne9s',
#         'expanded_url': 'http://itv.com/wales',
#         'display_url': 'itv.com/wales',
#         'indices': [0, 22]}]},
#      'description': {'urls': [{'url': 'https://t.co/p0kGsvP13M',
#         'expanded_url': 'http://facebook.com/itvwales/',
#         'display_url': 'facebook.com/itvwales/',
#         'indices': [78, 101]},
#        {'url': 'https://t.co/nDcD2LUq2d',
#         'expanded_url': 'http://instagram.com/itvwales',
#         'display_url': 'instagram.com/itvwales',
#         'indices': [104, 127]}]}},
#     'protected': False,
#     'followers_count': 85444,
#     'friends_count': 1262,
#     'listed_count': 618,
#     'created_at': 'Thu Jul 15 10:59:09 +0000 2010',
#     'favourites_count': 531,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 64050,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1166284135004028928/XxWv5YUy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1166284135004028928/XxWv5YUy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/166942410/1566898983',
#     'profile_link_color': '006473',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1254,
#    'favorite_count': 3885,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'retweet_count': 1425,
#   'favorite_count': 13421,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 02 19:48:42 +0000 2020',
#   'id': 1245800342660546560,
#   'id_str': '1245800342660546560',
#   'text': 'Why is Bill a juice man now? Play the new smart speaker quiz to find out!\n\nJust order your smart speaker to do your… https://t.co/5Y4XdQVAfw',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/5Y4XdQVAfw',
#      'expanded_url': 'https://twitter.com/i/web/status/1245800342660546560',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 13784322,
#    'id_str': '13784322',
#    'name': 'waitwait',
#    'screen_name': 'waitwait',
#    'location': 'Chicago, USA',
#    'description': 'The oddly informative news quiz from NPR',
#    'url': 'http://t.co/rAlUqTdOgD',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/rAlUqTdOgD',
#        'expanded_url': 'http://waitwait.npr.org',
#        'display_url': 'waitwait.npr.org',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 190309,
#    'friends_count': 222,
#    'listed_count': 4567,
#    'created_at': 'Thu Feb 21 19:29:43 +0000 2008',
#    'favourites_count': 1571,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 7455,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1179055744076976128/pj3hu6NS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1179055744076976128/pj3hu6NS_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/13784322/1533135725',
#    'profile_link_color': '089FD6',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'D8E6ED',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 5,
#   'favorite_count': 41,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 02 19:21:18 +0000 2020',
#   'id': 1245793446679453697,
#   'id_str': '1245793446679453697',
#   'text': "Has quarantine led you to talking to inanimate objects throughout your house? Good news, you're not alone. \n\nOn thi… https://t.co/PB56FXUquO",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/PB56FXUquO',
#      'expanded_url': 'https://twitter.com/i/web/status/1245793446679453697',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 13784322,
#    'id_str': '13784322',
#    'name': 'waitwait',
#    'screen_name': 'waitwait',
#    'location': 'Chicago, USA',
#    'description': 'The oddly informative news quiz from NPR',
#    'url': 'http://t.co/rAlUqTdOgD',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/rAlUqTdOgD',
#        'expanded_url': 'http://waitwait.npr.org',
#        'display_url': 'waitwait.npr.org',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 190309,
#    'friends_count': 222,
#    'listed_count': 4567,
#    'created_at': 'Thu Feb 21 19:29:43 +0000 2008',
#    'favourites_count': 1571,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 7455,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1179055744076976128/pj3hu6NS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1179055744076976128/pj3hu6NS_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/13784322/1533135725',
#    'profile_link_color': '089FD6',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'D8E6ED',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 11,
#   'favorite_count': 50,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'}]
