# %%
import twitter
import pandas as pd

# %%
consumer_key = '3hadC5cGfmdfYqVQ3EClF0VZd'
secret_key ='kjIfrQrSokxLirRZ21HstrJOJQZvuM9FmUDkNpRYrYjmhLtyWK'

access_token = '374743137-e4C4fLpqDqfjv7dVpe5S9SFQbWKZ9Ii8ci3dFa53'
secret_token = 'tGsYrurk2euQwZwaf2vZeuJCBQNTTYl7tiPmF7Qqffq2S'

# %%
from twitter import *
t = twitter.api.Twitter(auth=OAuth(access_token , secret_token, consumer_key, secret_key))
t.statuses.home_timeline()[0]
# Out:
# {'created_at': 'Sat Apr 04 17:25:42 +0000 2020',
#  'id': 1246489134006493185,
#  'id_str': '1246489134006493185',
#  'text': 'Here are 24 things I want you to know about @TheKalenAllen. https://t.co/4LrekC9YBA',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'TheKalenAllen',
#     'name': 'Kalen Allen',
#     'id': 171685697,
#     'id_str': '171685697',
#     'indices': [44, 58]}],
#   'urls': [],
#   'media': [{'id': 1246488139440553992,
#     'id_str': '1246488139440553992',
#     'indices': [60, 83],
#     'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1246488139440553992/img/o2qOtiXpXtNK7u4v.jpg',
#     'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1246488139440553992/img/o2qOtiXpXtNK7u4v.jpg',
#     'url': 'https://t.co/4LrekC9YBA',
#     'display_url': 'pic.twitter.com/4LrekC9YBA',
#     'expanded_url': 'https://twitter.com/TheEllenShow/status/1246489134006493185/video/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#      'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#      'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#  'extended_entities': {'media': [{'id': 1246488139440553992,
#     'id_str': '1246488139440553992',
#     'indices': [60, 83],
#     'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1246488139440553992/img/o2qOtiXpXtNK7u4v.jpg',
#     'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1246488139440553992/img/o2qOtiXpXtNK7u4v.jpg',
#     'url': 'https://t.co/4LrekC9YBA',
#     'display_url': 'pic.twitter.com/4LrekC9YBA',
#     'expanded_url': 'https://twitter.com/TheEllenShow/status/1246489134006493185/video/1',
#     'type': 'video',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#      'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#      'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#     'video_info': {'aspect_ratio': [16, 9],
#      'duration_millis': 196997,
#      'variants': [{'bitrate': 832000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/amplify_video/1246488139440553992/vid/640x360/qQWQRwi1ZZnd7_V2.mp4?tag=13'},
#       {'bitrate': 2176000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/amplify_video/1246488139440553992/vid/1280x720/MvtujffAH7VALaJp.mp4?tag=13'},
#       {'content_type': 'application/x-mpegURL',
#        'url': 'https://video.twimg.com/amplify_video/1246488139440553992/pl/hpw_5kxu237KDtKt.m3u8?tag=13'},
#       {'bitrate': 288000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/amplify_video/1246488139440553992/vid/480x270/YSDqsQd8vOwJKBOf.mp4?tag=13'}]},
#     'additional_media_info': {'title': '',
#      'description': '',
#      'embeddable': True,
#      'monetizable': True}}]},
#  'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 15846407,
#   'id_str': '15846407',
#   'name': 'Ellen DeGeneres',
#   'screen_name': 'TheEllenShow',
#   'location': 'California',
#   'description': 'Comedian, talk show host and ice road trucker. My tweets are real, and they’re spectacular. @ellentube @theellenfund',
#   'url': 'https://t.co/Z6A8XcDD9J',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/Z6A8XcDD9J',
#       'expanded_url': 'https://www.ellentube.com/',
#       'display_url': 'ellentube.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 80002465,
#   'friends_count': 27590,
#   'listed_count': 107071,
#   'created_at': 'Thu Aug 14 03:50:42 +0000 2008',
#   'favourites_count': 2137,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 21598,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': True,
#   'profile_background_color': '3ABEE3',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214282022828400640/Qd-vYi1E_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15846407/1578444252',
#   'profile_link_color': '3ABEE3',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'C4C6CC',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': True,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'regular'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 59,
#  'favorite_count': 738,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'lang': 'en'}

# %%
help(t)
# Out:
# Help on Twitter in module twitter.api object:
#
# class Twitter(TwitterCall)
#  |  Twitter(format='json', domain='api.twitter.com', secure=True, auth=None, api_version=<class 'twitter.api._DEFAULT'>, retry=False)
#  |
#  |  The minimalist yet fully featured Twitter API class.
#  |
#  |  Get RESTful data by accessing members of this class. The result
#  |  is decoded python objects (lists and dicts).
#  |
#  |  The Twitter API is documented at:
#  |
#  |    https://dev.twitter.com/overview/documentation
#  |
#  |  The list of most accessible functions is listed at:
#  |
#  |    https://dev.twitter.com/rest/public
#  |
#  |
#  |  Examples::
#  |
#  |      from twitter import *
#  |
#  |      t = Twitter(
#  |          auth=OAuth(token, token_secret, consumer_key, consumer_secret))
#  |
#  |      # Get your "home" timeline
#  |      t.statuses.home_timeline()
#  |
#  |      # Get a particular friend's timeline
#  |      t.statuses.user_timeline(screen_name="billybob")
#  |
#  |      # to pass in GET/POST parameters, such as `count`
#  |      t.statuses.home_timeline(count=5)
#  |
#  |      # to pass in the GET/POST parameter `id` you need to use `_id`
#  |      t.statuses.oembed(_id=1234567890)
#  |
#  |      # Update your status
#  |      t.statuses.update(
#  |          status="Using @sixohsix's sweet Python Twitter Tools.")
#  |
#  |      # Send a direct message
#  |      t.direct_messages.new(
#  |          user="billybob",
#  |          text="I think yer swell!")
#  |
#  |      # Get the members of tamtar's list "Things That Are Rad"
#  |      t.lists.members(owner_screen_name="tamtar", slug="things-that-are-rad")
#  |
#  |      # An *optional* `_timeout` parameter can also be used for API
#  |      # calls which take much more time than normal or twitter stops
#  |      # responding for some reason:
#  |      t.users.lookup(
#  |          screen_name=','.join(A_LIST_OF_100_SCREEN_NAMES),             _timeout=1)
#  |
#  |      # Overriding Method: GET/POST
#  |      # you should not need to use this method as this library properly
#  |      # detects whether GET or POST should be used, Nevertheless
#  |      # to force a particular method, use `_method`
#  |      t.statuses.oembed(_id=1234567890, _method='GET')
#  |
#  |      # Send images along with your tweets:
#  |      # - first just read images from the web or from files the regular way:
#  |      with open("example.png", "rb") as imagefile:
#  |          imagedata = imagefile.read()
#  |      # - then upload medias one by one on Twitter's dedicated server
#  |      #   and collect each one's id:
#  |      t_upload = Twitter(domain='upload.twitter.com',
#  |          auth=OAuth(token, token_secret, consumer_key, consumer_secret))
#  |      id_img1 = t_upload.media.upload(media=imagedata)["media_id_string"]
#  |      id_img2 = t_upload.media.upload(media=imagedata)["media_id_string"]
#  |
#  |      # - finally send your tweet with the list of media ids:
#  |      t.statuses.update(status="PTT ★", media_ids=",".join([id_img1, id_img2]))
#  |
#  |      # Or send a tweet with an image (or set a logo/banner similarily)
#  |      # using the old deprecated method that will probably disappear some day
#  |      params = {"media[]": imagedata, "status": "PTT ★"}
#  |      # Or for an image encoded as base64:
#  |      params = {"media[]": base64_image, "status": "PTT ★", "_base64": True}
#  |      t.statuses.update_with_media(**params)
#  |
#  |      # Attach text metadata to medias sent, using the upload.twitter.com route
#  |      # using the _json workaround to send json arguments as POST body
#  |      # (warning: to be done before attaching the media to a tweet)
#  |      t_upload.media.metadata.create(_json={
#  |        "media_id": id_img1,
#  |        "alt_text": { "text": "metadata generated via PTT!" }
#  |      })
#  |      # or with the shortcut arguments ("alt_text" and "text" work):
#  |      t_upload.media.metadata.create(media_id=id_img1, text="metadata generated via PTT!")
#  |
#  |  Searching Twitter::
#  |
#  |      # Search for the latest tweets about #pycon
#  |      t.search.tweets(q="#pycon")
#  |
#  |
#  |  Using the data returned
#  |  -----------------------
#  |
#  |  Twitter API calls return decoded JSON. This is converted into
#  |  a bunch of Python lists, dicts, ints, and strings. For example::
#  |
#  |      x = twitter.statuses.home_timeline()
#  |
#  |      # The first 'tweet' in the timeline
#  |      x[0]
#  |
#  |      # The screen name of the user who wrote the first 'tweet'
#  |      x[0]['user']['screen_name']
#  |
#  |
#  |  Getting raw XML data
#  |  --------------------
#  |
#  |  If you prefer to get your Twitter data in XML format, pass
#  |  format="xml" to the Twitter object when you instantiate it::
#  |
#  |      twitter = Twitter(format="xml")
#  |
#  |  The output will not be parsed in any way. It will be a raw string
#  |  of XML.
#  |
#  |  Method resolution order:
#  |      Twitter
#  |      TwitterCall
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, format='json', domain='api.twitter.com', secure=True, auth=None, api_version=<class 'twitter.api._DEFAULT'>, retry=False)
#  |      Create a new twitter API connector.
#  |
#  |      Pass an `auth` parameter to use the credentials of a specific
#  |      user. Generally you'll want to pass an `OAuth`
#  |      instance::
#  |
#  |          twitter = Twitter(auth=OAuth(
#  |                  token, token_secret, consumer_key, consumer_secret))
#  |
#  |
#  |      `domain` lets you change the domain you are connecting. By
#  |      default it's `api.twitter.com`.
#  |
#  |      If `secure` is False you will connect with HTTP instead of
#  |      HTTPS.
#  |
#  |      `api_version` is used to set the base uri. By default it's
#  |      '1.1'.
#  |
#  |      If `retry` is True, API rate limits will automatically be
#  |      handled by waiting until the next reset, as indicated by
#  |      the X-Rate-Limit-Reset HTTP header. If retry is an integer,
#  |      it defines the number of retries attempted.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from TwitterCall:
#  |
#  |  __call__(self, **kwargs)
#  |      Call self as a function.
#  |
#  |  __getattr__(self, k)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from TwitterCall:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from TwitterCall:
#  |
#  |  TWITTER_UNAVAILABLE_WAIT = 30

# %%
#t.search.tweets(q='#covid')
resp = t.search.tweets(geocode='39.011795,-77.0431,1mi')
resp
# Out:
# {'statuses': [{'created_at': 'Sat Apr 04 17:58:11 +0000 2020',
#    'id': 1246497308398817281,
#    'id_str': '1246497308398817281',
#    'text': '@wormz4brain I wish I liked in the U.K. 😪',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'wormz4brain',
#       'name': 'daisie✿',
#       'id': 742748421455515648,
#       'id_str': '742748421455515648',
#       'indices': [0, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1246496620100947968,
#    'in_reply_to_status_id_str': '1246496620100947968',
#    'in_reply_to_user_id': 742748421455515648,
#    'in_reply_to_user_id_str': '742748421455515648',
#    'in_reply_to_screen_name': 'wormz4brain',
#    'user': {'id': 2298103462,
#     'id_str': '2298103462',
#     'name': 'Emma💕 ☼',
#     'screen_name': 'emma_warnick',
#     'location': 'Silver Spring, MD',
#     'description': '🤠 was @accioselfesteem',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 659,
#     'friends_count': 707,
#     'listed_count': 7,
#     'created_at': 'Wed Jan 22 21:37:45 +0000 2014',
#     'favourites_count': 122760,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 47187,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2298103462/1497747476',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Apr 04 17:52:36 +0000 2020',
#    'id': 1246495901247516673,
#    'id_str': '1246495901247516673',
#    'text': 'Wow so whenever all of my locals say they have no clue who Declan McKenna is they’re lying?!??! Wow I can’t believe… https://t.co/rlBz49HLZC',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/rlBz49HLZC',
#       'expanded_url': 'https://twitter.com/i/web/status/1246495901247516673',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2298103462,
#     'id_str': '2298103462',
#     'name': 'Emma💕 ☼',
#     'screen_name': 'emma_warnick',
#     'location': 'Silver Spring, MD',
#     'description': '🤠 was @accioselfesteem',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 659,
#     'friends_count': 707,
#     'listed_count': 7,
#     'created_at': 'Wed Jan 22 21:37:45 +0000 2014',
#     'favourites_count': 122760,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 47187,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2298103462/1497747476',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Apr 04 17:32:31 +0000 2020',
#    'id': 1246490849485217793,
#    'id_str': '1246490849485217793',
#    'text': 'Lmao why are these in my drafts why didn’t I ever tweet them https://t.co/jfaelegw9V',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1246490846486282242,
#       'id_str': '1246490846486282242',
#       'indices': [61, 84],
#       'media_url': 'http://pbs.twimg.com/media/EUxs0hiXQAITG_O.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EUxs0hiXQAITG_O.jpg',
#       'url': 'https://t.co/jfaelegw9V',
#       'display_url': 'pic.twitter.com/jfaelegw9V',
#       'expanded_url': 'https://twitter.com/emma_warnick/status/1246490849485217793/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 285, 'resize': 'fit'},
#        'large': {'w': 828, 'h': 347, 'resize': 'fit'},
#        'medium': {'w': 828, 'h': 347, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1246490846486282242,
#       'id_str': '1246490846486282242',
#       'indices': [61, 84],
#       'media_url': 'http://pbs.twimg.com/media/EUxs0hiXQAITG_O.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EUxs0hiXQAITG_O.jpg',
#       'url': 'https://t.co/jfaelegw9V',
#       'display_url': 'pic.twitter.com/jfaelegw9V',
#       'expanded_url': 'https://twitter.com/emma_warnick/status/1246490849485217793/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 285, 'resize': 'fit'},
#        'large': {'w': 828, 'h': 347, 'resize': 'fit'},
#        'medium': {'w': 828, 'h': 347, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2298103462,
#     'id_str': '2298103462',
#     'name': 'Emma💕 ☼',
#     'screen_name': 'emma_warnick',
#     'location': 'Silver Spring, MD',
#     'description': '🤠 was @accioselfesteem',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 659,
#     'friends_count': 707,
#     'listed_count': 7,
#     'created_at': 'Wed Jan 22 21:37:45 +0000 2014',
#     'favourites_count': 122760,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 47187,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2298103462/1497747476',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 7,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Apr 04 15:42:45 +0000 2020',
#    'id': 1246463223823396864,
#    'id_str': '1246463223823396864',
#    'text': 'Stop staring at the clock every day. It\'s time for a new career. Follow us to view jobs with titles like "Neuro-onc… https://t.co/DXyZCYByI1',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/DXyZCYByI1',
#       'expanded_url': 'https://twitter.com/i/web/status/1246463223823396864',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.careerarc.com" rel="nofollow">CareerArc 2.0</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 274481682,
#     'id_str': '274481682',
#     'name': 'Maryland Neurology',
#     'screen_name': 'tmj_MD_neuro',
#     'location': 'Maryland',
#     'description': 'Follow this account for geo-targeted Physician-Neurology job tweets in Maryland Non-Metro. Need help? Tweet us at @CareerArc!',
#     'url': 'https://t.co/Ni3FBmK3PT',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Ni3FBmK3PT',
#         'expanded_url': 'http://bit.ly/2FmL7nC',
#         'display_url': 'bit.ly/2FmL7nC',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 106,
#     'friends_count': 54,
#     'listed_count': 3,
#     'created_at': 'Wed Mar 30 11:30:33 +0000 2011',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '253956',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/715182309247479808/BZpf9SZW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/715182309247479808/BZpf9SZW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/274481682/1459347727',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': {'type': 'Point', 'coordinates': [39.0041504, -77.0391754]},
#    'coordinates': {'type': 'Point', 'coordinates': [-77.0391754, 39.0041504]},
#    'place': {'id': '6417871953fa5e86',
#     'url': 'https://api.twitter.com/1.1/geo/id/6417871953fa5e86.json',
#     'place_type': 'city',
#     'name': 'Silver Spring',
#     'full_name': 'Silver Spring, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.064086, 38.979735],
#        [-76.97162, 38.979735],
#        [-76.97162, 39.036964],
#        [-77.064086, 39.036964]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Apr 04 15:37:13 +0000 2020',
#    'id': 1246461832623251456,
#    'id_str': '1246461832623251456',
#    'text': 'What Sgt. Skinner says. https://t.co/KwHnCyu541',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/KwHnCyu541',
#       'expanded_url': 'https://twitter.com/skinnerpm/status/1246425484432474113',
#       'display_url': 'twitter.com/skinnerpm/stat…',
#       'indices': [24, 47]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 10048562,
#     'id_str': '10048562',
#     'name': '~ Feral Church Lady in Pearls ~',
#     'screen_name': 'bravegirl01',
#     'location': 'Silver Spring, MD',
#     'description': "Former Floridian, current Marylander. Apparently I'm a professional anarchist. I thought I was a Church Lady. Views only mine. #NoMuslimBanEver",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 634,
#     'friends_count': 2944,
#     'listed_count': 40,
#     'created_at': 'Wed Nov 07 23:11:45 +0000 2007',
#     'favourites_count': 123879,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 16587,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FAD089',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/799595216332357632/DND2jOwb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799595216332357632/DND2jOwb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10048562/1479473360',
#     'profile_link_color': '915EFF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F5634A',
#     'profile_text_color': '3B8183',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1246425484432474113,
#    'quoted_status_id_str': '1246425484432474113',
#    'quoted_status': {'created_at': 'Sat Apr 04 13:12:47 +0000 2020',
#     'id': 1246425484432474113,
#     'id_str': '1246425484432474113',
#     'text': 'Many of the loudest dim bulbs of social influence are spending far more time trying to prove the coronavirus pandem… https://t.co/J2gcmbmcB1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/J2gcmbmcB1',
#        'expanded_url': 'https://twitter.com/i/web/status/1246425484432474113',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1120308836,
#      'id_str': '1120308836',
#      'name': 'Patrick Skinner',
#      'screen_name': 'SkinnerPm',
#      'location': 'I’m where I’m supposed to be',
#      'description': 'this is the most intentional thing I’ll ever do. I’ve made my way from intel/CT work overseas to local cop in my home town. I’m a truly terrible twitter follow',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 43035,
#      'friends_count': 1459,
#      'listed_count': 393,
#      'created_at': 'Fri Jan 25 21:29:13 +0000 2013',
#      'favourites_count': 12361,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 38616,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1197483744514510850/cE3mlQxK_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1197483744514510850/cE3mlQxK_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1120308836/1585429443',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 53,
#     'favorite_count': 298,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'retweet_count': 2,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Apr 04 15:10:01 +0000 2020',
#    'id': 1246454985707139077,
#    'id_str': '1246454985707139077',
#    'text': 'Horowitz is probably next on the hit list. https://t.co/kzc9kIJsbn',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/kzc9kIJsbn',
#       'expanded_url': 'https://twitter.com/natashabertrand/status/1246435229700587524',
#       'display_url': 'twitter.com/natashabertran…',
#       'indices': [43, 66]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 10048562,
#     'id_str': '10048562',
#     'name': '~ Feral Church Lady in Pearls ~',
#     'screen_name': 'bravegirl01',
#     'location': 'Silver Spring, MD',
#     'description': "Former Floridian, current Marylander. Apparently I'm a professional anarchist. I thought I was a Church Lady. Views only mine. #NoMuslimBanEver",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 634,
#     'friends_count': 2944,
#     'listed_count': 40,
#     'created_at': 'Wed Nov 07 23:11:45 +0000 2007',
#     'favourites_count': 123879,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 16587,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FAD089',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/799595216332357632/DND2jOwb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799595216332357632/DND2jOwb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10048562/1479473360',
#     'profile_link_color': '915EFF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F5634A',
#     'profile_text_color': '3B8183',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1246435229700587524,
#    'quoted_status_id_str': '1246435229700587524',
#    'quoted_status': {'created_at': 'Sat Apr 04 13:51:31 +0000 2020',
#     'id': 1246435229700587524,
#     'id_str': '1246435229700587524',
#     'text': 'Late last night, DOJ inspector general Michael Horowitz—who also chairs CIGIE—released this striking statement: “IG… https://t.co/WTjzie2i0a',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/WTjzie2i0a',
#        'expanded_url': 'https://twitter.com/i/web/status/1246435229700587524',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 372536101,
#      'id_str': '372536101',
#      'name': 'Natasha Bertrand',
#      'screen_name': 'NatashaBertrand',
#      'location': 'Washington, DC',
#      'description': 'National security correspondent @politico. @MSNBC contributor. Send tips: nbertrand@politico.com nbertrand@protonmail.com. DM for Signal #.',
#      'url': 'https://t.co/e0ItgsD6Co',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/e0ItgsD6Co',
#          'expanded_url': 'https://www.politico.com/staff/natasha-bertrand',
#          'display_url': 'politico.com/staff/natasha-…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 619063,
#      'friends_count': 5130,
#      'listed_count': 6061,
#      'created_at': 'Mon Sep 12 23:21:14 +0000 2011',
#      'favourites_count': 35394,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 23419,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C6E2EE',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1238500899607261184/LhfGhGEy_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1238500899607261184/LhfGhGEy_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/372536101/1584116571',
#      'profile_link_color': '1F97C7',
#      'profile_sidebar_border_color': 'C6E2EE',
#      'profile_sidebar_fill_color': 'DAECF4',
#      'profile_text_color': '663B12',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'regular'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5856,
#     'favorite_count': 12959,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Apr 04 13:38:35 +0000 2020',
#    'id': 1246431977256951808,
#    'id_str': '1246431977256951808',
#    'text': '@DeclanMcKenna when are you on tomorrow morning because I want to wake up early for it but if you’re not on in the… https://t.co/AP9dn5i1W5',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DeclanMcKenna',
#       'name': 'Declan McKenna',
#       'id': 1257539816,
#       'id_str': '1257539816',
#       'indices': [0, 14]}],
#     'urls': [{'url': 'https://t.co/AP9dn5i1W5',
#       'expanded_url': 'https://twitter.com/i/web/status/1246431977256951808',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': 1257539816,
#    'in_reply_to_user_id_str': '1257539816',
#    'in_reply_to_screen_name': 'DeclanMcKenna',
#    'user': {'id': 2298103462,
#     'id_str': '2298103462',
#     'name': 'Emma💕 ☼',
#     'screen_name': 'emma_warnick',
#     'location': 'Silver Spring, MD',
#     'description': '🤠 was @accioselfesteem',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 659,
#     'friends_count': 707,
#     'listed_count': 7,
#     'created_at': 'Wed Jan 22 21:37:45 +0000 2014',
#     'favourites_count': 122760,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 47187,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2298103462/1497747476',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Apr 04 02:18:36 +0000 2020',
#    'id': 1246260852216475655,
#    'id_str': '1246260852216475655',
#    'text': '@tomaawroblewski Ewakuowałem Emmę do Maryland. Wróciłem jednym strzałem omijając NYC. Jak Ty się masz i Twoja rodzina ?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tomaawroblewski',
#       'name': 'Tomasz Wróblewski',
#       'id': 956024672,
#       'id_str': '956024672',
#       'indices': [0, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pl', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1246178977162702848,
#    'in_reply_to_status_id_str': '1246178977162702848',
#    'in_reply_to_user_id': 956024672,
#    'in_reply_to_user_id_str': '956024672',
#    'in_reply_to_screen_name': 'tomaawroblewski',
#    'user': {'id': 2242365024,
#     'id_str': '2242365024',
#     'name': 'Tadek Zachurski',
#     'screen_name': 'Zachurski',
#     'location': 'Washington, DC - New York, NY',
#     'description': 'Antediluvian Correspondent of Polish and Polish-American Media. Odwieczny- od roku 1987- amerykański korespondent polskich (i polonijnych) mediów.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 185,
#     'friends_count': 613,
#     'listed_count': 1,
#     'created_at': 'Thu Dec 12 13:24:35 +0000 2013',
#     'favourites_count': 314,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 685,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1224005265030307842/qBsqBlXK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1224005265030307842/qBsqBlXK_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pl'},
#   {'created_at': 'Sat Apr 04 01:10:36 +0000 2020',
#    'id': 1246243740118913031,
#    'id_str': '1246243740118913031',
#    'text': 'Thinking about how Zeros was supposed to come out right before my birthday on the day I was supposed to go to Europ… https://t.co/Mte4RSav4h',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Mte4RSav4h',
#       'expanded_url': 'https://twitter.com/i/web/status/1246243740118913031',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2298103462,
#     'id_str': '2298103462',
#     'name': 'Emma💕 ☼',
#     'screen_name': 'emma_warnick',
#     'location': 'Silver Spring, MD',
#     'description': '🤠 was @accioselfesteem',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 659,
#     'friends_count': 707,
#     'listed_count': 7,
#     'created_at': 'Wed Jan 22 21:37:45 +0000 2014',
#     'favourites_count': 122760,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 47187,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2298103462/1497747476',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 11,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Apr 04 00:34:17 +0000 2020',
#    'id': 1246234602802417665,
#    'id_str': '1246234602802417665',
#    'text': '@shirhallelujah I try to have some at home all the time. They always cheer me up.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'shirhallelujah',
#       'name': 'Laura Shir',
#       'id': 100600188,
#       'id_str': '100600188',
#       'indices': [0, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1246234292348424192,
#    'in_reply_to_status_id_str': '1246234292348424192',
#    'in_reply_to_user_id': 100600188,
#    'in_reply_to_user_id_str': '100600188',
#    'in_reply_to_screen_name': 'shirhallelujah',
#    'user': {'id': 1135819927,
#     'id_str': '1135819927',
#     'name': 'Michigan Girl ready for ⚾️',
#     'screen_name': 'amaiznblugrl',
#     'location': '',
#     'description': 'Nats ⚾️ Caps 🏒 University of Michigan 〽️💛💙 #HSI member',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 465,
#     'friends_count': 768,
#     'listed_count': 8,
#     'created_at': 'Thu Jan 31 02:37:18 +0000 2013',
#     'favourites_count': 134699,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 5786,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1189770902327758848/p9TP_2-h_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1189770902327758848/p9TP_2-h_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1135819927/1446483801',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Apr 04 00:33:05 +0000 2020',
#    'id': 1246234299067703296,
#    'id_str': '1246234299067703296',
#    'text': 'I have no idea who she is but wow I might have to stan after this https://t.co/MVKhNkpG37',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/MVKhNkpG37',
#       'expanded_url': 'https://twitter.com/thepophub/status/1246135954038853632',
#       'display_url': 'twitter.com/thepophub/stat…',
#       'indices': [66, 89]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2298103462,
#     'id_str': '2298103462',
#     'name': 'Emma💕 ☼',
#     'screen_name': 'emma_warnick',
#     'location': 'Silver Spring, MD',
#     'description': '🤠 was @accioselfesteem',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 659,
#     'friends_count': 707,
#     'listed_count': 7,
#     'created_at': 'Wed Jan 22 21:37:45 +0000 2014',
#     'favourites_count': 122760,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 47187,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245893551029977088/fHkcCbLg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2298103462/1497747476',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1246135954038853632,
#    'quoted_status_id_str': '1246135954038853632',
#    'quoted_status': {'created_at': 'Fri Apr 03 18:02:18 +0000 2020',
#     'id': 1246135954038853632,
#     'id_str': '1246135954038853632',
#     'text': 'Hyolyn absolutely nails the viral Megan Thee Stallion “Savage” TikTok challenge. 😍 https://t.co/igFgdQOegv',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1245993625109975041,
#        'id_str': '1245993625109975041',
#        'indices': [83, 106],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245993625109975041/pu/img/jknM-DNN9yMGXC_m.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245993625109975041/pu/img/jknM-DNN9yMGXC_m.jpg',
#        'url': 'https://t.co/igFgdQOegv',
#        'display_url': 'pic.twitter.com/igFgdQOegv',
#        'expanded_url': 'https://twitter.com/gooodlooks/status/1245993683993804803/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 576, 'h': 1024, 'resize': 'fit'},
#         'medium': {'w': 576, 'h': 1024, 'resize': 'fit'}},
#        'source_status_id': 1245993683993804803,
#        'source_status_id_str': '1245993683993804803',
#        'source_user_id': 1051018007672053760,
#        'source_user_id_str': '1051018007672053760'}]},
#     'extended_entities': {'media': [{'id': 1245993625109975041,
#        'id_str': '1245993625109975041',
#        'indices': [83, 106],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245993625109975041/pu/img/jknM-DNN9yMGXC_m.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245993625109975041/pu/img/jknM-DNN9yMGXC_m.jpg',
#        'url': 'https://t.co/igFgdQOegv',
#        'display_url': 'pic.twitter.com/igFgdQOegv',
#        'expanded_url': 'https://twitter.com/gooodlooks/status/1245993683993804803/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 576, 'h': 1024, 'resize': 'fit'},
#         'medium': {'w': 576, 'h': 1024, 'resize': 'fit'}},
#        'source_status_id': 1245993683993804803,
#        'source_status_id_str': '1245993683993804803',
#        'source_user_id': 1051018007672053760,
#        'source_user_id_str': '1051018007672053760',
#        'video_info': {'aspect_ratio': [9, 16],
#         'duration_millis': 15282,
#         'variants': [{'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1245993625109975041/pu/vid/360x640/nztFVhbnMMmjdeo6.mp4?tag=10'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1245993625109975041/pu/pl/GYnLhvl8PeYkepTg.m3u8?tag=10'},
#          {'bitrate': 632000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1245993625109975041/pu/vid/320x568/BsDaqaNwRzobQJUV.mp4?tag=10'},
#          {'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1245993625109975041/pu/vid/576x1024/I7YeFkzyb0UFmaZu.mp4?tag=10'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 900047040134213638,
#      'id_str': '900047040134213638',
#      'name': 'The Pop Hub',
#      'screen_name': 'ThePopHub',
#      'location': 'Home. As should you be. ',
#      'description': 'The Pop Hub is the only unbiased and reliable source for your latest news on western & K-Pop culture. For promotion & more, send us a DM or visit our website.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 76036,
#      'friends_count': 5435,
#      'listed_count': 607,
#      'created_at': 'Tue Aug 22 17:28:31 +0000 2017',
#      'favourites_count': 6600,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5560,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1156261267167952897/qqXa4Rjf_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1156261267167952897/qqXa4Rjf_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/900047040134213638/1566595802',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4003,
#     'favorite_count': 18092,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Apr 03 21:41:19 +0000 2020',
#    'id': 1246191071312392192,
#    'id_str': '1246191071312392192',
#    'text': 'Spotted on my walk. https://t.co/m2IK9acOWH',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1246191060126248960,
#       'id_str': '1246191060126248960',
#       'indices': [20, 43],
#       'media_url': 'http://pbs.twimg.com/media/EUtcKqUXsAA8Wfp.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EUtcKqUXsAA8Wfp.jpg',
#       'url': 'https://t.co/m2IK9acOWH',
#       'display_url': 'pic.twitter.com/m2IK9acOWH',
#       'expanded_url': 'https://twitter.com/petramatic/status/1246191071312392192/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 2048, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1246191060126248960,
#       'id_str': '1246191060126248960',
#       'indices': [20, 43],
#       'media_url': 'http://pbs.twimg.com/media/EUtcKqUXsAA8Wfp.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EUtcKqUXsAA8Wfp.jpg',
#       'url': 'https://t.co/m2IK9acOWH',
#       'display_url': 'pic.twitter.com/m2IK9acOWH',
#       'expanded_url': 'https://twitter.com/petramatic/status/1246191071312392192/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 2048, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 141283162,
#     'id_str': '141283162',
#     'name': 'petra mayer',
#     'screen_name': 'petramatic',
#     'location': 'Washington, DC',
#     'description': "Editor, NPR Books. Hot glue enthusiast. Buster Keaton's secret girlfriend. Public Radio Nerd. TOS is the One True Trek, don't @ me. She/her.",
#     'url': 'https://t.co/JtZw4Q7YZ8',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/JtZw4Q7YZ8',
#         'expanded_url': 'http://books.npr.org',
#         'display_url': 'books.npr.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8111,
#     'friends_count': 650,
#     'listed_count': 247,
#     'created_at': 'Fri May 07 17:23:55 +0000 2010',
#     'favourites_count': 19397,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 3665,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'B2DFDA',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1237380210556878848/wgbh_dIS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1237380210556878848/wgbh_dIS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/141283162/1561563205',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '07d9c9a4fd086002',
#     'url': 'https://api.twitter.com/1.1/geo/id/07d9c9a4fd086002.json',
#     'place_type': 'poi',
#     'name': 'Sligo Creek Park',
#     'full_name': 'Sligo Creek Park',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.02596187591553, 39.0096804557876],
#        [-77.02596187591553, 39.0096804557876],
#        [-77.02596187591553, 39.0096804557876],
#        [-77.02596187591553, 39.0096804557876]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 8,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Apr 03 21:28:42 +0000 2020',
#    'id': 1246187895683153925,
#    'id_str': '1246187895683153925',
#    'text': 'https://t.co/mNXvJwfiNt',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/mNXvJwfiNt',
#       'expanded_url': 'https://youtu.be/6iKU6SObZQQ',
#       'display_url': 'youtu.be/6iKU6SObZQQ',
#       'indices': [0, 23]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 68117386,
#     'id_str': '68117386',
#     'name': 'Victor Sesan',
#     'screen_name': 'ohlaz',
#     'location': 'Maryland, USA',
#     'description': '#forex #Renko #trader #Investor #linux #cloud #options',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 427,
#     'friends_count': 1221,
#     'listed_count': 7,
#     'created_at': 'Sun Aug 23 10:14:28 +0000 2009',
#     'favourites_count': 1904,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2837,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1223992905917968385/pp5pPVOL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1223992905917968385/pp5pPVOL_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/68117386/1579627750',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '832793dfbf3477cb',
#     'url': 'https://api.twitter.com/1.1/geo/id/832793dfbf3477cb.json',
#     'place_type': 'city',
#     'name': 'Forest Glen',
#     'full_name': 'Forest Glen, MD',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.060658, 39.013369],
#        [-77.030226, 39.013369],
#        [-77.030226, 39.029771],
#        [-77.060658, 39.029771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'}],
#  'search_metadata': {'completed_in': 0.104,
#   'max_id': 1246497308398817281,
#   'max_id_str': '1246497308398817281',
#   'next_results': '?max_id=1246187895683153924&q=&geocode=39.011795%2C-77.0431%2C1mi&include_entities=1',
#   'query': '',
#   'refresh_url': '?since_id=1246497308398817281&q=&geocode=39.011795%2C-77.0431%2C1mi&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
for i in resp['statuses']:
    print(i['text'])
# Out:
# @wormz4brain I wish I liked in the U.K. 😪
# Wow so whenever all of my locals say they have no clue who Declan McKenna is they’re lying?!??! Wow I can’t believe… https://t.co/rlBz49HLZC
# Lmao why are these in my drafts why didn’t I ever tweet them https://t.co/jfaelegw9V
# Stop staring at the clock every day. It's time for a new career. Follow us to view jobs with titles like "Neuro-onc… https://t.co/DXyZCYByI1
# What Sgt. Skinner says. https://t.co/KwHnCyu541
# Horowitz is probably next on the hit list. https://t.co/kzc9kIJsbn
# @DeclanMcKenna when are you on tomorrow morning because I want to wake up early for it but if you’re not on in the… https://t.co/AP9dn5i1W5
# @tomaawroblewski Ewakuowałem Emmę do Maryland. Wróciłem jednym strzałem omijając NYC. Jak Ty się masz i Twoja rodzina ?
# Thinking about how Zeros was supposed to come out right before my birthday on the day I was supposed to go to Europ… https://t.co/Mte4RSav4h
# @shirhallelujah I try to have some at home all the time. They always cheer me up.
# I have no idea who she is but wow I might have to stan after this https://t.co/MVKhNkpG37
# Spotted on my walk. https://t.co/m2IK9acOWH
# https://t.co/mNXvJwfiNt

# %%
status = resp['statuses'][0]

# %%
for i in status['text']:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# h
# a
# n
# g
# i
# n
# g
#
# i
# n
#
# t
# h
# e
# r
# e
#
# w
# i
# t
# h
#
# t
# h
# i
# s
#
# C
# O
# V
# I
# D
#
# 1
# 9
# .
#
# K
# e
# e
# p
# i
# n
# g
#
# i
# n
#
# c
# o
# n
# t
# a
# c
# t
#
# d
# a
# i
# l
# y
#
# w
# i
# t
# h
#
# f
# r
# i
# e
# n
# d
# s
#
# a
# n
# d
#
# f
# a
# m
# i
# l
# y
#
# t
# h
# r
# o
# u
# g
# h
#
# t
# e
# c
# h
# n
# o
# l
# o
# g
# y
# .
#
# h
# t
# t
# p
# s
# :
# /
# /
# t
# .
# c
# o
# /
# e
# U
# O
# F
# N
# 7
# M
# 8
# R
# z
